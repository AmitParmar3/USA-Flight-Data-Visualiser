# %%
pip install pandas numpy pyarrow duckdb matplotlib seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))


from src.ingestion import load_bts_flight_data

df = load_bts_flight_data(
    year=2025,
    month=1
)
# Out:
# Loading: D:\Projects\Flight Logs\data\raw\bts\2025\01\Jan2025.csv
# Loaded 539,747 rows and 54 columns.

# %%
df.head()
# Out:
#    YEAR  MONTH               FL_DATE OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  \
# 0  2025      1  1/1/2025 12:00:00 AM                AA                  1
# 1  2025      1  1/1/2025 12:00:00 AM                AA                 10
# 2  2025      1  1/1/2025 12:00:00 AM                AA               1002
# 3  2025      1  1/1/2025 12:00:00 AM                AA               1004
# 4  2025      1  1/1/2025 12:00:00 AM                AA               1005
#
#    ORIGIN_AIRPORT_ID ORIGIN  ORIGIN_CITY_NAME ORIGIN_STATE_ABR  \
# 0              12478    JFK      New York, NY               NY
# 1              12892    LAX   Los Angeles, CA               CA
# 2              13485    MSN       Madison, WI               WI
# 3              14100    PHL  Philadelphia, PA               PA
# 4              13930    ORD       Chicago, IL               IL
#
#   ORIGIN_STATE_NM  ...  FIRST_DEP_TIME TOTAL_ADD_GTIME LONGEST_ADD_GTIME  \
# ...

# %%
df.shape
# Out:
# (539747, 54)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 539747 entries, 0 to 539746
# Data columns (total 54 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   YEAR                     539747 non-null  int64
#  1   MONTH                    539747 non-null  int64
#  2   FL_DATE                  539747 non-null  str
#  3   OP_UNIQUE_CARRIER        539747 non-null  str
#  4   OP_CARRIER_FL_NUM        539747 non-null  int64
#  5   ORIGIN_AIRPORT_ID        539747 non-null  int64
#  6   ORIGIN                   539747 non-null  str
#  7   ORIGIN_CITY_NAME         539747 non-null  str
#  8   ORIGIN_STATE_ABR         539747 non-null  str
#  9   ORIGIN_STATE_NM          539747 non-null  str
#  10  DEST_AIRPORT_ID          539747 non-null  int64
#  11  DEST                     539747 non-null  str
#  12  DEST_CITY_NAME           539747 non-null  str
#  13  DEST_STATE_ABR           539747 non-null  str
# ...

# %%
df.columns.tolist()
# Out:
# ['YEAR',
#  'MONTH',
#  'FL_DATE',
#  'OP_UNIQUE_CARRIER',
#  'OP_CARRIER_FL_NUM',
#  'ORIGIN_AIRPORT_ID',
#  'ORIGIN',
#  'ORIGIN_CITY_NAME',
#  'ORIGIN_STATE_ABR',
#  'ORIGIN_STATE_NM',
#  'DEST_AIRPORT_ID',
#  'DEST',
#  'DEST_CITY_NAME',
#  'DEST_STATE_ABR',
#  'CRS_DEP_TIME',
#  'DEP_TIME',
#  'DEP_DELAY',
#  'DEP_DELAY_NEW',
#  'DEP_DEL15',
#  'DEP_DELAY_GROUP',
#  'DEP_TIME_BLK',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'CRS_ARR_TIME',
#  'ARR_TIME',
#  'ARR_DELAY',
#  'ARR_DELAY_NEW',
#  'ARR_DEL15',
#  'ARR_TIME_BLK',
#  'CANCELLED',
#  'CANCELLATION_CODE',
#  'DIVERTED',
#  'CRS_ELAPSED_TIME',
#  'ACTUAL_ELAPSED_TIME',
#  'AIR_TIME',
#  'FLIGHTS',
#  'DISTANCE',
#  'CARRIER_DELAY',
#  'WEATHER_DELAY',
#  'NAS_DELAY',
#  'SECURITY_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  'FIRST_DEP_TIME',
#  'TOTAL_ADD_GTIME',
#  'LONGEST_ADD_GTIME',
#  'DIV_AIRPORT_LANDINGS',
#  'DIV_REACHED_DEST',
#  'DIV_ACTUAL_ELAPSED_TIME',
#  'DIV_ARR_DELAY',
#  'DIV_DISTANCE',
# ...

# %%
df.isna().sum()
# Out:
# YEAR                            0
# MONTH                           0
# FL_DATE                         0
# OP_UNIQUE_CARRIER               0
# OP_CARRIER_FL_NUM               0
# ORIGIN_AIRPORT_ID               0
# ORIGIN                          0
# ORIGIN_CITY_NAME                0
# ORIGIN_STATE_ABR                0
# ORIGIN_STATE_NM                 0
# DEST_AIRPORT_ID                 0
# DEST                            0
# DEST_CITY_NAME                  0
# DEST_STATE_ABR                  0
# CRS_DEP_TIME                    0
# DEP_TIME                    15886
# DEP_DELAY                   15923
# DEP_DELAY_NEW               15923
# DEP_DEL15                   15923
# DEP_DELAY_GROUP             15923
# DEP_TIME_BLK                    0
# TAXI_OUT                    16227
# WHEELS_OFF                  16227
# WHEELS_ON                   16580
# TAXI_IN                     16580
# CRS_ARR_TIME                    0
# ARR_TIME                    16580
# ...

# %%
df["OP_UNIQUE_CARRIER"].nunique()
# Out:
# 14

# %%
df["ORIGIN"].nunique()
# Out:
# 329

# %%
df["DEST"].nunique()
# Out:
# 329

# %%
df["CANCELLED"].value_counts()
# Out:
# CANCELLED
# 0.0    523435
# 1.0     16312
# Name: count, dtype: int64

# %%
df["DIVERTED"].value_counts()
# Out:
# DIVERTED
# 0.0    538581
# 1.0      1166
# Name: count, dtype: int64

# %%
df["ARR_DEL15"].value_counts(dropna=False)
# Out:
# ARR_DEL15
# 0.0    424139
# 1.0     98130
# NaN     17478
# Name: count, dtype: int64

# %%
df["DEP_DEL15"].value_counts(dropna=False)
# Out:
# DEP_DEL15
# 0.0    428164
# 1.0     95660
# NaN     15923
# Name: count, dtype: int64

# %%
pd.crosstab(df["CANCELLED"], df["ARR_DEL15"], dropna=False)
# Out:
# ARR_DEL15     0.0    1.0    NaN
# CANCELLED
# 0.0        424139  98130   1166
# 1.0             0      0  16312

# %%
pd.crosstab(df["DIVERTED"], df["ARR_DEL15"], dropna=False)
# Out:
# ARR_DEL15     0.0    1.0    NaN
# DIVERTED
# 0.0        424139  98130  16312
# 1.0             0      0   1166

# %%
pd.crosstab(df["CANCELLED"], df["DEP_DEL15"], dropna=False)
# Out:
# DEP_DEL15     0.0    1.0    NaN
# CANCELLED
# 0.0        428003  95432      0
# 1.0           161    228  15923

# %%
pd.crosstab(df["CANCELLED"], df["DIVERTED"])
# Out:
# DIVERTED      0.0   1.0
# CANCELLED
# 0.0        522269  1166
# 1.0         16312     0

# %%
df["OP_UNIQUE_CARRIER"].nunique()
# Out:
# 14

# %%
df["OP_UNIQUE_CARRIER"].value_counts()
# Out:
# OP_UNIQUE_CARRIER
# WN    105307
# DL     76306
# AA     75088
# OO     65036
# UA     62007
# YX     27833
# MQ     21890
# OH     21094
# AS     18163
# B6     17918
# NK     17544
# F9     15526
# G4      9345
# HA      6690
# Name: count, dtype: int64

# %%
df["ORIGIN"].nunique()
df["DEST"].nunique()
df["ORIGIN"].value_counts().head(20)
# Out:
# ORIGIN
# DFW    25124
# DEN    24732
# ATL    23881
# ORD    21643
# CLT    16877
# PHX    15956
# LAX    15157
# LAS    15007
# MCO    13058
# SEA    11882
# DCA    11734
# LGA    10905
# SFO    10839
# BOS    10624
# MIA    10182
# EWR    10144
# SLC     9350
# DTW     9253
# IAH     9250
# MSP     8483
# Name: count, dtype: int64

# %%
df["DEST"].value_counts().head(20)
# Out:
# DEST
# DFW    25125
# DEN    24740
# ATL    23881
# ORD    21641
# CLT    16883
# PHX    15949
# LAX    15143
# LAS    15004
# MCO    13052
# SEA    11893
# DCA    11740
# LGA    10909
# SFO    10832
# BOS    10622
# MIA    10184
# EWR    10139
# SLC     9347
# IAH     9257
# DTW     9254
# MSP     8480
# Name: count, dtype: int64

# %%
df["FL_DATE"] = pd.to_datetime(df["FL_DATE"])

df["FL_DATE"].head()
# Out:
# C:\Users\parma\AppData\Local\Temp\ipykernel_1844\2795176422.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["FL_DATE"] = pd.to_datetime(df["FL_DATE"])
# 0   2025-01-01
# 1   2025-01-01
# 2   2025-01-01
# 3   2025-01-01
# 4   2025-01-01
# Name: FL_DATE, dtype: datetime64[us]

# %%
df["FL_DATE"].dtype
# Out:
# dtype('<M8[us]')

# %%
df["YEAR"] = df["FL_DATE"].dt.year
df["MONTH"] = df["FL_DATE"].dt.month
df["DAY"] = df["FL_DATE"].dt.day
df["DAY_OF_WEEK"] = df["FL_DATE"].dt.day_name()
df["DAY_OF_WEEK_NUM"] = df["FL_DATE"].dt.dayofweek
df["IS_WEEKEND"] = df["DAY_OF_WEEK_NUM"] >= 5

df[[
    "FL_DATE",
    "YEAR",
    "MONTH",
    "DAY",
    "DAY_OF_WEEK",
    "DAY_OF_WEEK_NUM",
    "IS_WEEKEND"
]].head(10)
# Out:
#      FL_DATE  YEAR  MONTH  DAY DAY_OF_WEEK  DAY_OF_WEEK_NUM  IS_WEEKEND
# 0 2025-01-01  2025      1    1   Wednesday                2       False
# 1 2025-01-01  2025      1    1   Wednesday                2       False
# 2 2025-01-01  2025      1    1   Wednesday                2       False
# 3 2025-01-01  2025      1    1   Wednesday                2       False
# 4 2025-01-01  2025      1    1   Wednesday                2       False
# 5 2025-01-01  2025      1    1   Wednesday                2       False
# 6 2025-01-01  2025      1    1   Wednesday                2       False
# 7 2025-01-01  2025      1    1   Wednesday                2       False
# 8 2025-01-01  2025      1    1   Wednesday                2       False
# 9 2025-01-01  2025      1    1   Wednesday                2       False

# %%
df[[
    "FL_DATE",
    "CRS_DEP_TIME",
    "DEP_TIME",
    "CRS_ARR_TIME",
    "ARR_TIME"
]].head(20)

df[[
    "CRS_DEP_TIME",
    "DEP_TIME",
    "CRS_ARR_TIME",
    "ARR_TIME"
]].describe()

df[[
    "CRS_DEP_TIME",
    "DEP_TIME",
    "CRS_ARR_TIME",
    "ARR_TIME"
]].isna().sum()
# Out:
# CRS_DEP_TIME        0
# DEP_TIME        15886
# CRS_ARR_TIME        0
# ARR_TIME        16580
# dtype: int64

# %%
df[[
    "FL_DATE",
    "CRS_DEP_TIME",
    "DEP_TIME",
    "CRS_ARR_TIME",
    "ARR_TIME"
]].head(20)
# Out:
#       FL_DATE  CRS_DEP_TIME  DEP_TIME  CRS_ARR_TIME  ARR_TIME
# 0  2025-01-01           659     656.0          1020    1013.0
# 1  2025-01-01          2200    2153.0           630     543.0
# 2  2025-01-01           644     720.0          1005    1025.0
# 3  2025-01-01          1855    1856.0          2134    2127.0
# 4  2025-01-01           830     829.0          1131    1215.0
# 5  2025-01-01          1634    1640.0          1927    1922.0
# 6  2025-01-01          1500    1500.0          1554    1552.0
# 7  2025-01-01          2042    2036.0          2153    2147.0
# 8  2025-01-01          1915    1912.0          2125    2117.0
# 9  2025-01-01          1100    1142.0          1713    1749.0
# 10 2025-01-01          2040    2249.0          2221      20.0
# 11 2025-01-01          1227    1241.0          1610    1540.0
# 12 2025-01-01           700     657.0          1020    1022.0
# 13 2025-01-01          2140    2137.0          2248    2242.0
# ...

# %%
# Convert BTS HHMM values into hours and minutes
def time_to_timedelta(series):
    series = series.astype("Int64")
    
    hours = series // 100
    minutes = series % 100
    
    return pd.to_timedelta(hours, unit="h") + pd.to_timedelta(minutes, unit="m")


# Create scheduled timestamps
df["SCHEDULED_DEP_TS"] = (
    df["FL_DATE"] + time_to_timedelta(df["CRS_DEP_TIME"])
)

df["SCHEDULED_ARR_TS"] = (
    df["FL_DATE"] + time_to_timedelta(df["CRS_ARR_TIME"])
)


# Create actual timestamps
df["ACTUAL_DEP_TS"] = (
    df["FL_DATE"] + time_to_timedelta(df["DEP_TIME"])
)

df["ACTUAL_ARR_TS"] = (
    df["FL_DATE"] + time_to_timedelta(df["ARR_TIME"])
)


# Correct overnight scheduled arrivals
overnight_scheduled = (
    df["SCHEDULED_ARR_TS"] < df["SCHEDULED_DEP_TS"]
)

df.loc[overnight_scheduled, "SCHEDULED_ARR_TS"] += pd.Timedelta(days=1)


# Correct overnight actual arrivals
overnight_actual = (
    df["ACTUAL_ARR_TS"] < df["ACTUAL_DEP_TS"]
)

df.loc[overnight_actual, "ACTUAL_ARR_TS"] += pd.Timedelta(days=1)

# %%
df.loc[10, [
    "FL_DATE",
    "CRS_DEP_TIME",
    "DEP_TIME",
    "CRS_ARR_TIME",
    "ARR_TIME",
    "SCHEDULED_DEP_TS",
    "SCHEDULED_ARR_TS",
    "ACTUAL_DEP_TS",
    "ACTUAL_ARR_TS"
]]
# Out:
# FL_DATE             2025-01-01 00:00:00
# CRS_DEP_TIME                       2040
# DEP_TIME                         2249.0
# CRS_ARR_TIME                       2221
# ARR_TIME                           20.0
# SCHEDULED_DEP_TS    2025-01-01 20:40:00
# SCHEDULED_ARR_TS    2025-01-01 22:21:00
# ACTUAL_DEP_TS       2025-01-01 22:49:00
# ACTUAL_ARR_TS       2025-01-02 00:20:00
# Name: 10, dtype: object

# %%
df["CALCULATED_SCHEDULED_DURATION_MIN"] = (
    df["SCHEDULED_ARR_TS"] - df["SCHEDULED_DEP_TS"]
).dt.total_seconds() / 60

df["CALCULATED_ACTUAL_DURATION_MIN"] = (
    df["ACTUAL_ARR_TS"] - df["ACTUAL_DEP_TS"]
).dt.total_seconds() / 60

df[[
    "CRS_ELAPSED_TIME",
    "CALCULATED_SCHEDULED_DURATION_MIN",
    "ACTUAL_ELAPSED_TIME",
    "CALCULATED_ACTUAL_DURATION_MIN"
]].head(20)
# Out:
#     CRS_ELAPSED_TIME  CALCULATED_SCHEDULED_DURATION_MIN  ACTUAL_ELAPSED_TIME  \
# 0              381.0                              201.0                377.0
# 1              330.0                              510.0                290.0
# 2              141.0                              201.0                125.0
# 3              339.0                              159.0                331.0
# 4              241.0                              181.0                286.0
# 5              113.0                              173.0                102.0
# 6              114.0                               54.0                112.0
# 7              131.0                               71.0                131.0
# 8              130.0                              130.0                125.0
# 9              253.0                              373.0                247.0
# 10             101.0                              101.0                 91.0
# ...

# %%
df["SCHEDULED_DURATION_DIFF"] = (
    df["CALCULATED_SCHEDULED_DURATION_MIN"]
    - df["CRS_ELAPSED_TIME"]
)

df["ACTUAL_DURATION_DIFF"] = (
    df["CALCULATED_ACTUAL_DURATION_MIN"]
    - df["ACTUAL_ELAPSED_TIME"]
)

# %%
df[[
    "SCHEDULED_DURATION_DIFF",
    "ACTUAL_DURATION_DIFF"
]].describe()
# Out:
#        SCHEDULED_DURATION_DIFF  ACTUAL_DURATION_DIFF
# count            539747.000000         522269.000000
# mean                  0.846889              2.562473
# std                  75.670336             89.412980
# min                -300.000000           -300.000000
# 25%                 -60.000000            -60.000000
# 50%                   0.000000              0.000000
# 75%                  60.000000             60.000000
# max                1380.000000           1380.000000

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

sys.path.insert(0, str(PROJECT_ROOT))

from src.ingestion import load_bts_flight_data

# %%
raw_df = load_bts_flight_data(2025, 1)
# Out:
# Loading: D:\Projects\Flight Logs\data\raw\bts\2025\01\Jan2025.csv
# Loaded 539,747 rows and 54 columns.

# %%
raw_df.head()
raw_df.shape
# Out:
# (539747, 54)

# %%
print(f"Rows: {len(raw_df):,}")
print(f"Columns: {len(raw_df.columns)}")
raw_df.columns.tolist()
# Out:
# Rows: 539,747
# Columns: 54
# ['YEAR',
#  'MONTH',
#  'FL_DATE',
#  'OP_UNIQUE_CARRIER',
#  'OP_CARRIER_FL_NUM',
#  'ORIGIN_AIRPORT_ID',
#  'ORIGIN',
#  'ORIGIN_CITY_NAME',
#  'ORIGIN_STATE_ABR',
#  'ORIGIN_STATE_NM',
#  'DEST_AIRPORT_ID',
#  'DEST',
#  'DEST_CITY_NAME',
#  'DEST_STATE_ABR',
#  'CRS_DEP_TIME',
#  'DEP_TIME',
#  'DEP_DELAY',
#  'DEP_DELAY_NEW',
#  'DEP_DEL15',
#  'DEP_DELAY_GROUP',
#  'DEP_TIME_BLK',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'CRS_ARR_TIME',
#  'ARR_TIME',
#  'ARR_DELAY',
#  'ARR_DELAY_NEW',
#  'ARR_DEL15',
#  'ARR_TIME_BLK',
#  'CANCELLED',
#  'CANCELLATION_CODE',
#  'DIVERTED',
#  'CRS_ELAPSED_TIME',
#  'ACTUAL_ELAPSED_TIME',
#  'AIR_TIME',
#  'FLIGHTS',
#  'DISTANCE',
#  'CARRIER_DELAY',
#  'WEATHER_DELAY',
#  'NAS_DELAY',
#  'SECURITY_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  'FIRST_DEP_TIME',
#  'TOTAL_ADD_GTIME',
#  'LONGEST_ADD_GTIME',
#  'DIV_AIRPORT_LANDINGS',
#  'DIV_REACHED_DEST',
#  'DIV_ACTUAL_ELAPSED_TIME',
# ...

# %%
from src.ingestion import load_bts_flight_data
from src.cleaning import clean_bts_flight_data

# %%
clean_df = clean_bts_flight_data(raw_df)
# Out:
# d:\Projects\Flight Logs\src\cleaning.py:20: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["FL_DATE"] = pd.to_datetime(

# %%
print("Raw shape:   ", raw_df.shape)
print("Clean shape: ", clean_df.shape)
# Out:
# Raw shape:    (539747, 54)
# Clean shape:  (539747, 69)

# %%
clean_df.columns.tolist()
# Out:
# ['YEAR',
#  'MONTH',
#  'FL_DATE',
#  'OP_UNIQUE_CARRIER',
#  'OP_CARRIER_FL_NUM',
#  'ORIGIN_AIRPORT_ID',
#  'ORIGIN',
#  'ORIGIN_CITY_NAME',
#  'ORIGIN_STATE_ABR',
#  'ORIGIN_STATE_NM',
#  'DEST_AIRPORT_ID',
#  'DEST',
#  'DEST_CITY_NAME',
#  'DEST_STATE_ABR',
#  'CRS_DEP_TIME',
#  'DEP_TIME',
#  'DEP_DELAY',
#  'DEP_DELAY_NEW',
#  'DEP_DEL15',
#  'DEP_DELAY_GROUP',
#  'DEP_TIME_BLK',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'CRS_ARR_TIME',
#  'ARR_TIME',
#  'ARR_DELAY',
#  'ARR_DELAY_NEW',
#  'ARR_DEL15',
#  'ARR_TIME_BLK',
#  'CANCELLED',
#  'CANCELLATION_CODE',
#  'DIVERTED',
#  'CRS_ELAPSED_TIME',
#  'ACTUAL_ELAPSED_TIME',
#  'AIR_TIME',
#  'FLIGHTS',
#  'DISTANCE',
#  'CARRIER_DELAY',
#  'WEATHER_DELAY',
#  'NAS_DELAY',
#  'SECURITY_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  'FIRST_DEP_TIME',
#  'TOTAL_ADD_GTIME',
#  'LONGEST_ADD_GTIME',
#  'DIV_AIRPORT_LANDINGS',
#  'DIV_REACHED_DEST',
#  'DIV_ACTUAL_ELAPSED_TIME',
#  'DIV_ARR_DELAY',
#  'DIV_DISTANCE',
# ...

# %%
clean_df[
    [
        "FL_DATE",
        "OP_UNIQUE_CARRIER",
        "ORIGIN",
        "DEST",
        "ROUTE",
        "FLIGHT_STATUS",
        "DEP_DELAY",
        "ARR_DELAY",
        "DEP_DELAY_CATEGORY",
        "ARR_DELAY_CATEGORY"
    ]
].head(10)
# Out:
#      FL_DATE OP_UNIQUE_CARRIER ORIGIN DEST    ROUTE FLIGHT_STATUS  DEP_DELAY  \
# 0 2025-01-01                AA    JFK  LAX  JFK-LAX     COMPLETED       -3.0
# 1 2025-01-01                AA    LAX  JFK  LAX-JFK     COMPLETED       -7.0
# 2 2025-01-01                AA    MSN  CLT  MSN-CLT     COMPLETED       36.0
# 3 2025-01-01                AA    PHL  LAS  PHL-LAS     COMPLETED        1.0
# 4 2025-01-01                AA    ORD  PHX  ORD-PHX     COMPLETED       -1.0
# 5 2025-01-01                AA    COS  DFW  COS-DFW     COMPLETED        6.0
# 6 2025-01-01                AA    DFW  COS  DFW-COS     COMPLETED        0.0
# 7 2025-01-01                AA    CLT  STL  CLT-STL     COMPLETED       -6.0
# 8 2025-01-01                AA    LGA  CLT  LGA-CLT     COMPLETED       -3.0
# 9 2025-01-01                AA    EGE  MIA  EGE-MIA     COMPLETED       42.0
#
#    ARR_DELAY DEP_DELAY_CATEGORY ARR_DELAY_CATEGORY
# 0       -7.0              Early              Early
# ...

# %%
from src.validation import validate_flight_data, validation_summary
validation_results = validate_flight_data(clean_df)

validation_summary(validation_results)
# Out:
#                          CHECK  VALUE STATUS
# 0               duplicate_rows      0   PASS
# 1          missing_flight_date      0   PASS
# 2               invalid_status      0   PASS
# 3            negative_distance      0   PASS
# 4  negative_scheduled_duration      0   PASS
# 5         cancelled_with_delay      0   PASS
# 6       cancelled_and_diverted      0   PASS

# %%
from src.transformations import create_flight_fact_table

# %%
from src.transformations import create_flight_fact_table

import src.transformations
importlib.reload(src.transformations)
flight_fact = create_flight_fact_table(clean_df)
print(flight_fact.shape)
flight_fact.head()
flight_fact.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
import importlib
import src.transformations

importlib.reload(src.transformations)

from src.transformations import create_flight_fact_table

flight_fact = create_flight_fact_table(clean_df)

# %%
flight_fact[
    [
        "flight_id",
        "flight_date",
        "carrier",
        "flight_number",
        "origin",
        "destination"
    ]
].head()
print("Rows:", len(flight_fact))
print("Unique flight IDs:", flight_fact["flight_id"].nunique())

# %%
import importlib
import src.analytics

importlib.reload(src.analytics)

carrier_route_metrics = (
    src.analytics.calculate_carrier_route_metrics(
        flight_fact
    )
)

carrier_route_metrics.shape
carrier_route_reliable = carrier_route_metrics[
    carrier_route_metrics["total_flights"] >= 100
].copy()

carrier_route_reliable.sort_values(
    "arrival_delay_rate",
    ascending=False
).head(20)

carrier_route_reliable.sort_values(
    "arrival_delay_rate",
    ascending=True
).head(20)

# %%
import importlib
import src.analytics

importlib.reload(src.analytics)

day_metrics = src.analytics.calculate_day_of_week_metrics(
    flight_fact
)

day_metrics.sort_values(
    "day_of_week_num"
)

# %%
from src.transformations import create_flight_fact_table

flight_fact = create_flight_fact_table(clean_df)

import importlib
import src.transformations

importlib.reload(src.transformations)

flight_fact = src.transformations.create_flight_fact_table(
    clean_df
)

flight_fact.columns.tolist()

# %%
[
    column
    for column in [
        "CARRIER_DELAY",
        "WEATHER_DELAY",
        "NAS_DELAY",
        "SECURITY_DELAY",
        "LATE_AIRCRAFT_DELAY"
    ]
    if column in clean_df.columns
]

# %%
importlib.reload(src.analytics)

delay_cause_metrics = (
    src.analytics.calculate_delay_cause_metrics(
        flight_fact
    )
)

delay_cause_metrics

# %%
print(flight_fact.columns.tolist())

# %%
import importlib
import src.analytics

importlib.reload(src.analytics)

carrier_delay_cause_metrics = (
    src.analytics.calculate_carrier_delay_cause_metrics(flight_fact)
)

carrier_delay_cause_metrics.head(20)

carrier_delay_cause_metrics[
    carrier_delay_cause_metrics["carrier"] == "AA"
]

# %%
day_of_week_metrics = (
    src.analytics.calculate_day_of_week_metrics(flight_fact)
)

day_of_week_metrics

day_of_week_metrics.sort_values(
    "arrival_delay_rate",
    ascending=False
)

day_of_week_metrics.sort_values(
    "cancellation_rate",
    ascending=False
)

# %%
pip install airportsdata

# %%
import importlib
import src.transformations

importlib.reload(src.transformations)

from src.transformations import add_airport_timezones

flight_data_tz = add_airport_timezones(clean_df)

flight_data_tz[
    ["ORIGIN", "ORIGIN_TIMEZONE", "DEST", "DEST_TIMEZONE"]
].head(20)

print(
    "Missing origin timezone:",
    flight_data_tz["ORIGIN_TIMEZONE"].isna().sum()
)

print(
    "Missing destination timezone:",
    flight_data_tz["DEST_TIMEZONE"].isna().sum()
)

# %%
import importlib
import src.transformations

importlib.reload(src.transformations)

from src.transformations import create_flight_timestamps

flight_data_timestamps = create_flight_timestamps(
    flight_data_tz
)

flight_data_timestamps[
    [
        "FL_DATE",
        "ORIGIN",
        "DEST",
        "CRS_DEP_TIME",
        "CRS_ARR_TIME",
        "SCHEDULED_DEPARTURE_LOCAL",
        "SCHEDULED_ARRIVAL_LOCAL"
    ]
].head(20)

# %%
import importlib
import src.transformations

importlib.reload(src.transformations)

from src.transformations import localize_airport_timestamps

# %%
flight_data_timestamps = localize_airport_timestamps(
    flight_data_timestamps,
    "SCHEDULED_DEPARTURE_LOCAL",
    "ORIGIN_TIMEZONE",
    "SCHEDULED_DEPARTURE_AWARE"
)

flight_data_timestamps = localize_airport_timestamps(
    flight_data_timestamps,
    "SCHEDULED_ARRIVAL_LOCAL",
    "DEST_TIMEZONE",
    "SCHEDULED_ARRIVAL_AWARE"
)

flight_data_timestamps[
    [
        "ORIGIN",
        "ORIGIN_TIMEZONE",
        "DEST",
        "DEST_TIMEZONE",
        "SCHEDULED_DEPARTURE_AWARE",
        "SCHEDULED_ARRIVAL_AWARE"
    ]
].head(10)

# %%
from zoneinfo import ZoneInfo

flight_data_timestamps["SCHEDULED_DEPARTURE_UTC"] = (
    flight_data_timestamps["SCHEDULED_DEPARTURE_AWARE"]
    .apply(
        lambda x: x.astimezone(ZoneInfo("UTC"))
        if pd.notna(x)
        else pd.NaT
    )
)

flight_data_timestamps["SCHEDULED_ARRIVAL_UTC"] = (
    flight_data_timestamps["SCHEDULED_ARRIVAL_AWARE"]
    .apply(
        lambda x: x.astimezone(ZoneInfo("UTC"))
        if pd.notna(x)
        else pd.NaT
    )
)

# %%
flight_data_timestamps[
    [
        "ORIGIN",
        "DEST",
        "SCHEDULED_DEPARTURE_AWARE",
        "SCHEDULED_ARRIVAL_AWARE",
        "SCHEDULED_DEPARTURE_UTC",
        "SCHEDULED_ARRIVAL_UTC"
    ]
].head()

flight_data_timestamps["CALCULATED_SCHEDULED_DURATION_MIN"] = (
    (
        flight_data_timestamps["SCHEDULED_ARRIVAL_UTC"]
        - flight_data_timestamps["SCHEDULED_DEPARTURE_UTC"]
    )
    .dt.total_seconds()
    / 60
)

# %%
duration_check = flight_data_timestamps[
    [
        "ORIGIN",
        "DEST",
        "CRS_ELAPSED_TIME",
        "CALCULATED_SCHEDULED_DURATION_MIN"
    ]
].copy()

duration_check["DURATION_DIFFERENCE"] = (
    duration_check["CALCULATED_SCHEDULED_DURATION_MIN"]
    - duration_check["CRS_ELAPSED_TIME"]
)

duration_check.head(20)

# %%
duration_check["DURATION_DIFFERENCE"].describe()
duration_check[
    duration_check["DURATION_DIFFERENCE"].abs() == 1440
].shape

bad_duration = flight_data_timestamps[
    (
        (
            flight_data_timestamps["CALCULATED_SCHEDULED_DURATION_MIN"]
            - flight_data_timestamps["CRS_ELAPSED_TIME"]
        ).abs() == 1440
    )
]

bad_duration[
    [
        "FL_DATE",
        "ORIGIN",
        "DEST",
        "CRS_DEP_TIME",
        "CRS_ARR_TIME",
        "SCHEDULED_DEPARTURE_LOCAL",
        "SCHEDULED_ARRIVAL_LOCAL",
        "SCHEDULED_DEPARTURE_AWARE",
        "SCHEDULED_ARRIVAL_AWARE",
        "SCHEDULED_DEPARTURE_UTC",
        "SCHEDULED_ARRIVAL_UTC",
        "CRS_ELAPSED_TIME",
        "CALCULATED_SCHEDULED_DURATION_MIN"
    ]
].head(20)

# %%
import importlib
import src.transformations as transformations

importlib.reload(transformations)

# %%
from src.transformations import (
    add_airport_timezones,
    create_flight_timestamps,
    create_flight_fact_table
)

flight_data_timestamps = create_flight_timestamps(
    add_airport_timezones(clean_df)
)

[
    column
    for column in flight_data_timestamps.columns
    if "TIME" in column or "DEPARTURE" in column or "ARRIVAL" in column
]

# %%
flight_data_timestamps[
    [
        "ORIGIN",
        "DEST",
        "CRS_DEP_TIME",
        "CRS_ARR_TIME",
        "CRS_ELAPSED_TIME",
        "SCHEDULED_DEPARTURE_AWARE",
        "SCHEDULED_DEPARTURE_UTC",
        "SCHEDULED_ARRIVAL_AWARE",
        "SCHEDULED_ARRIVAL_UTC"
    ]
].head(10)

# %%
flight_data_timestamps["CALCULATED_SCHEDULED_DURATION_MIN"] = (
    (
        flight_data_timestamps["SCHEDULED_ARRIVAL_UTC"]
        - flight_data_timestamps["SCHEDULED_DEPARTURE_UTC"]
    )
    .dt.total_seconds()
    / 60
)

flight_data_timestamps["SCHEDULED_DURATION_DIFFERENCE"] = (
    flight_data_timestamps["CALCULATED_SCHEDULED_DURATION_MIN"]
    - flight_data_timestamps["CRS_ELAPSED_TIME"]
)

# %%
flight_data_timestamps[
    "SCHEDULED_DURATION_DIFFERENCE"
].value_counts(dropna=False).head(20)

flight_data_timestamps[
    flight_data_timestamps["SCHEDULED_DURATION_DIFFERENCE"].abs() >= 1440
].shape

flight_data_timestamps["SCHEDULED_DURATION_DIFFERENCE"].describe()

# %%
flight_data_timestamps["CALCULATED_CRS_ARR_TIME"] = (
    flight_data_timestamps["SCHEDULED_ARRIVAL_LOCAL"].dt.hour * 100
    + flight_data_timestamps["SCHEDULED_ARRIVAL_LOCAL"].dt.minute
)

# %%
arrival_time_match = (
    flight_data_timestamps["CRS_ARR_TIME"]
    == flight_data_timestamps["CALCULATED_CRS_ARR_TIME"]
)

arrival_time_match.value_counts(dropna=False)

# %%
arrival_mismatches = flight_data_timestamps[
    ~arrival_time_match
][
    [
        "ORIGIN",
        "DEST",
        "FL_DATE",
        "CRS_DEP_TIME",
        "CRS_ARR_TIME",
        "CALCULATED_CRS_ARR_TIME",
        "CRS_ELAPSED_TIME",
        "SCHEDULED_DEPARTURE_AWARE",
        "SCHEDULED_ARRIVAL_AWARE"
    ]
]

arrival_mismatches

# %%
arrival_mismatches[
    [
        "ORIGIN",
        "DEST",
        "FL_DATE",
        "CRS_DEP_TIME",
        "CRS_ARR_TIME",
        "CRS_ELAPSED_TIME",
        "CANCELLED",
        "DIVERTED",
        "OP_UNIQUE_CARRIER",
        "OP_CARRIER_FL_NUM"
    ]
]

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
import pandas as pd

from src.ingestion import load_bts_flight_data
from src.cleaning import clean_bts_flight_data
from src.validation import validate_flight_data, validation_summary
from src.transformations import (
    add_airport_timezones,
    create_flight_timestamps,
    create_flight_fact_table
)

# %%
flight_data = load_bts_flight_data(
    year=2025,
    month=1
)

clean_df = clean_bts_flight_data(
    flight_data
)
flight_data_timestamps = create_flight_timestamps(
    add_airport_timezones(clean_df)
)

# %%
actual_arrival_mismatches = flight_data_timestamps[
    ~actual_arrival_match
    & flight_data_timestamps["ARR_TIME"].notna()
    & flight_data_timestamps["ACTUAL_ARRIVAL_LOCAL"].notna()
].copy()

# %%
remaining_arrival_mismatches = flight_data_timestamps[
    ~actual_arrival_match
    & flight_data_timestamps["ARR_TIME"].notna()
    & flight_data_timestamps["ACTUAL_ARRIVAL_LOCAL"].notna()
    & (flight_data_timestamps["ARR_TIME"] != 2400)
].copy()

remaining_arrival_mismatches[
    [
        "FL_DATE",
        "OP_UNIQUE_CARRIER",
        "OP_CARRIER_FL_NUM",
        "ORIGIN",
        "DEST",
        "DEP_TIME",
        "ARR_TIME",
        "ACTUAL_ELAPSED_TIME",
        "ACTUAL_ARRIVAL_AWARE",
        "ACTUAL_ARRIVAL_LOCAL",
        "ACTUAL_ARRIVAL_UTC",
    ]
]

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.transformations import (
    add_airport_timezones,
    create_flight_timestamps,
    create_flight_fact_table
)

# %%
flight_data_timestamps = create_flight_timestamps(
    add_airport_timezones(clean_df)
)

# %%
flight_fact = create_flight_fact_table(flight_data_timestamps)

print(flight_fact.columns.tolist())

# %%
import importlib
import src.transformations as transformations

importlib.reload(transformations)

create_flight_fact_table = transformations.create_flight_fact_table

flight_fact = create_flight_fact_table(flight_data_timestamps)

# %%
flight_fact[
    [
        "flight_id",
        "origin",
        "destination",
        "scheduled_duration_min",
        "actual_duration_min",
        "duration_deviation_min",
        "departure_delay_min",
        "arrival_delay_min"
    ]
].head(10)

# %%
flight_fact["duration_deviation_min"].describe(
    percentiles=[0.01, 0.05, 0.25, 0.50, 0.75, 0.95, 0.99]
)

# %%
import importlib
import src.transformations as transformations

importlib.reload(transformations)

create_flight_fact_table = transformations.create_flight_fact_table

flight_fact = create_flight_fact_table(flight_data_timestamps)

# %%
flight_fact[
    [
        "flight_id",
        "departure_delay_min",
        "arrival_delay_min",
        "delay_recovery_min"
    ]
].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 flight_fact[
#       2     [
#       3         "flight_id",
#       4         "departure_delay_min",
#
# NameError: name 'flight_fact' is not defined

# %%
from src.analytics import calculate_carrier_performance

carrier_performance = calculate_carrier_performance(flight_fact)

carrier_performance

# %%
import importlib
import src.transformations as transformations

importlib.reload(transformations)

create_flight_fact_table = transformations.create_flight_fact_table

flight_fact = create_flight_fact_table(flight_data_timestamps)

# %%
print("Rows:", len(flight_fact))
print("Columns:", len(flight_fact.columns))
print("Unique flight IDs:", flight_fact["flight_id"].nunique())

print("\nMissing actual duration:",
      flight_fact["actual_duration_min"].isna().sum())

print("Missing arrival delay:",
      flight_fact["arrival_delay_min"].isna().sum())

print("Missing delay recovery:",
      flight_fact["delay_recovery_min"].isna().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print("Rows:", len(flight_fact))
#       2 print("Columns:", len(flight_fact.columns))
#       3 print("Unique flight IDs:", flight_fact["flight_id"].nunique())
#       4
#
# NameError: name 'flight_fact' is not defined

# %%
import importlib
import src.analytics as analytics

importlib.reload(analytics)

calculate_airport_performance = analytics.calculate_airport_performance

airport_performance = calculate_airport_performance(flight_fact)

print(airport_performance.shape)
airport_performance.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       4 importlib.reload(analytics)
#       5
#       6 calculate_airport_performance = analytics.calculate_airport_performance
#       7
# ----> 8 airport_performance = calculate_airport_performance(flight_fact)
#       9
#      10 print(airport_performance.shape)
#      11 airport_performance.head()
#
# NameError: name 'flight_fact' is not defined

# %%
airport_performance[
    ["airport", "departure_flights", "arrival_flights"]
].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 airport_performance[
#       2     ["airport", "departure_flights", "arrival_flights"]
#       3 ].describe()
#
# NameError: name 'airport_performance' is not defined

# %%
for threshold in [50, 100, 250, 500, 1000, 2500]:
    count = (
        airport_performance["departure_flights"] >= threshold
    ).sum()
    print(f"{threshold:>5} flights: {count} airports")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 for threshold in [50, 100, 250, 500, 1000, 2500]:
#       2     count = (
# ----> 3         airport_performance["departure_flights"] >= threshold
#       4     ).sum()
#       5     print(f"{threshold:>5} flights: {count} airports")
#
# NameError: name 'airport_performance' is not defined

# %%
airport_performance.sort_values(
    "departure_flights",
    ascending=False
).head(20)[
    [
        "airport",
        "departure_flights",
        "departure_delay_rate",
        "departure_cancellation_rate",
        "arrival_delay_rate",
        "arrival_cancellation_rate"
    ]
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 airport_performance.sort_values(
#       2     "departure_flights",
#       3     ascending=False
#       4 ).head(20)[
#
# NameError: name 'airport_performance' is not defined
